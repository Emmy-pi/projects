# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\emman\Downloads\Binance_Cold_Wallet_1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date (UTC)             451 non-null    object
#  1   description            451 non-null    object
#  2   moneyIn (BTC)          451 non-null    float64
#  3   moneyOut (BTC)         451 non-null    float64
#  4   tx hash                451 non-null    object
#  5   current balance (BTC)  451 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# date (UTC)               0
# description              0
# moneyIn (BTC)            0
# moneyOut (BTC)           0
# tx hash                  0
# current balance (BTC)    0
# dtype: int64

# %%
for col in df.columns:
    print('The minimum value for {} is {}'. format(col,df[col].min()))
# Out:
# The minimum value for date (UTC) is 1/10/19 20:20
# The minimum value for description is PAYMENT RECEIVED
# The minimum value for moneyIn (BTC) is 0.0
# The minimum value for moneyOut (BTC) is -110572.3062
# The minimum value for tx hash is 0065ceb574e3cad14c873dd86af847a02ac2fc5a87b016ebe2902a7bc3aada79
# The minimum value for current balance (BTC) is 0.0

# %%
df.describe()
# Out:
#        moneyIn (BTC)  moneyOut (BTC)  current balance (BTC)
# count     451.000000      451.000000             451.000000
# mean     1567.724967    -1425.879924           83280.464814
# std      6902.776123     9624.950957           49048.813435
# min         0.000000  -110572.306200               0.000000
# 25%         0.001000        0.000000           49845.800135
# 50%      1105.507044        0.000000           75097.487410
# 75%      2000.000000        0.000000          126335.505850
# max    109234.330000        0.000000          179842.450700

# %%
df.head()
# Out:
#        date (UTC)       description  moneyIn (BTC)  moneyOut (BTC)  \
# 0    3/11/20 1:32      PAYMENT SENT       0.000000    -9464.165009
# 1  31/10/20 21:26  PAYMENT RECEIVED       0.000005        0.000000
# 2   15/10/20 5:41  PAYMENT RECEIVED       0.000005        0.000000
# 3   26/9/20 19:05  PAYMENT RECEIVED       0.000008        0.000000
# 4    24/9/20 5:42  PAYMENT RECEIVED       0.000005        0.000000
#
#                                              tx hash  current balance (BTC)
# 0  749a9bc4558408b16be0286e52fa63419b8ec432e6f6e5...            63972.11440
# 1  98a9b6abf87469eb411789c3189e8b8e7ed20757d105d0...            73436.27941
# 2  1efc9519cc2861a0101cf96a3addd1a9a142e017208b66...            73436.27941
# 3  e1fcbd7faa3bb6c26312c826eec31cc842d8f8a29c889e...            73436.27940
# 4  44e72630f5dbe176854faa978d48acef4ee6038ce36b8e...            73436.27939

# %%
df.shape
# Out:
# (451, 6)

# %%
df.sample(frac=0.1)
# Out:
#          date (UTC)       description  moneyIn (BTC)  moneyOut (BTC)  \
# 135  13/11/19 16:34  PAYMENT RECEIVED      30.407540         0.00000
# 230    4/7/19 16:43  PAYMENT RECEIVED    1016.944545         0.00000
# 258    2/6/19 10:23  PAYMENT RECEIVED    1997.261202         0.00000
# 209    1/7/19 18:37  PAYMENT RECEIVED    1736.652635         0.00000
# 354  23/12/18 18:35  PAYMENT RECEIVED    2000.000000         0.00000
# 305   14/3/19 16:54  PAYMENT RECEIVED       0.000010         0.00000
# 265   13/6/19 18:35  PAYMENT RECEIVED    1636.380296         0.00000
# 241    19/6/19 9:51  PAYMENT RECEIVED    2000.000000         0.00000
# 176    19/9/19 4:30  PAYMENT RECEIVED     870.377001         0.00000
# 277    29/5/19 9:12      PAYMENT SENT       0.000000    -72093.99321
# 398   15/11/18 6:47  PAYMENT RECEIVED  109234.330000         0.00000
# 391  20/11/18 19:29  PAYMENT RECEIVED     396.213181         0.00000
# 375  15/11/18 17:56  PAYMENT RECEIVED    2000.000000         0.00000
# ...

# %%
df=df.rename(columns= {"date (UTC)":"Date","description":'trnx','moneyIn (BTC)':'moneyIn', "moneyOut (BTC)":"moneyOut",'current balance (BTC)':'current_balance'  }, inplace= False)


df['Date']=pd.to_datetime(df['Date'])

plt.figure(figsize=(15,7))
sns.lineplot(x='Date', y='current_balance',data=df, palette= 'viridis')
plt.show()
